# %%
from matplotlib import pyplot as plt

import numpy as np

# %%
# generate some data

# f, (a0, a1) = plt.subplots(
#     2, 2,
#     gridspec_kw={
#         'height_ratios': [1, 1],
#         'width_ratios': [1, 2]
#     }
# )

plt.figure(figsize=(2*3, 2*2))

plt.subplot2grid((2, 3), (0, 0), colspan=1)
plt.title("PRCA")


plt.subplot2grid((2, 3), (1, 0), colspan=1)
plt.title("PRCA Sortabs")


plt.subplot2grid((2, 3), (0, 1), colspan=2, rowspan=2)
plt.title("Acc")
# a1.plot(x, y)
# a2.title("PRCA-sortabs")

plt.tight_layout()
# plt.savefig('grid_figure.pdf')
