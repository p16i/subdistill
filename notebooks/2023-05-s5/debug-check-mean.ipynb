# %%
import numpy as np

from pathlib import Path

from matplotlib import pyplot as plt

# %%
# !pip install .. .

# %%
DIR = ""

# %%
def load(path):
    
    return np.load(path)

mu = load(
    "../../artifacts/2023-05-S5/experiment-binary-task/imagenet-324vs325/imagenet-resnet18-tv/layer1/act_mean.npy"
)


mu2 = load(
    "../../artifacts/2023-05-S5/experiment-binary-task/imagenet-324vs325--n500/imagenet-resnet18-tv/layer1/act_mean.npy"
)

# %%
ev1 = load(
    "../../artifacts/2023-05-S5/experiment-binary-task/imagenet-324vs325/imagenet-resnet18-tv/layer1/prca--centered/eigvals.npy"
)


ev2 = load(
    "../../artifacts/2023-05-S5/experiment-binary-task/imagenet-325vs324/imagenet-resnet18-tv/layer1/prca--centered/eigvals.npy"
)

# %%
plt.plot(ev1); plt.plot(ev2)
