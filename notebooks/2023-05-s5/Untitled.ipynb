# %%
import re

# %%
txt = "something-5"

data = [
    "something",
    "something-55vs99",
    "something-55vs99-n50"
]

for t in data:
#     res = re.match(r"(^\w+)-(\d+)vs(\d+)-n(\d+)", t)
#     print(res)
    
    res = re.match(r"(^\w+)-?(\d+)?(vs?)(\d+)?-n(\d+)?", t)
    print(res)
    
    print("--------")
# Out:
# None
# --------
# None
# --------
# <re.Match object; span=(0, 20), match='something-55vs99-n50'>
# --------

# %%
res = re.match(r"(\d+)vs(\d+)", "55vs30")

res.group(1)
# Out:
# '55'

# %%
res
