# %%
import numpy as np

# %%
for seed in range(1, 5+1)[:1]:
    for sub in ["act", "ctx"]:
        run1_act = np.load(f"../../tmp/run-actctx1/cifar100-people-ts0.1-seed{seed}/arr_{sub}.npy")
        run2_act = np.load(f"../../tmp/run-actctx2/cifar100-people-ts0.1-seed{seed}/arr_{sub}.npy")
        np.testing.assert_allclose(run1_act, run2_act)

# %%
run1_act = np.load(f"./tmp/check-seed-run1/cifar100-people-ts0.1-seed1/arr_act.npy")
