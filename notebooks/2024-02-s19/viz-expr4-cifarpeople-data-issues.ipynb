# %%
import wandb

import pandas as pd

from tqdm import tqdm

from matplotlib import pyplot as plt

import numpy as np 

from xaikd import models, datasets

from torch.utils.data import DataLoader
from xaikd.utils import metrics

from contextlib import nullcontext

from datetime import datetime

from matplotlib import colormaps

# %%
api = wandb.Api()

# %%
EXPERIMENT_GROUP = "./artifacts/2024-02-s19/experiments/4-cifar100-data-scarcity.yml"

# %%
def read_data(
    teacher,
    student,
    dataset,
    policy,
    lambda_task,
    lambda_kd,
    training_size,
    contamination_level,
    verbose=False,
    
):
    use_val_split=False,

    
    runs = api.runs(
        f'p16i/xaikd-distillation-layerwise-s19',
        {
        "$and": [
            {"group": EXPERIMENT_GROUP},
            {"config.teacher": teacher},
            {"config.student": student},
            {"config.lambda_task": lambda_task},
            {"config.lambda_kd": lambda_kd},
            {"config.policy": policy},
            {"config.dataset": dataset},
            {"config.contamination_level": contamination_level},
            {"config.training_size": training_size},
            {"config.seed": {"$in":  [1, 2, 3]}}
        ]}
    )
    
    if verbose:
        print(f"we have {len(runs)} runs")
    
    rows = []
    
    count = 0
    datasets = []

    for run in runs:
        seed = run.config["seed"]
        
        if not "arr_metrics"in run.summary:
            print(">> bad run config")
            print(run.config)
            count += 1
            return run
            continue
            raise
            
                                 
        k = np.argmax(run.summary["arr_metrics"]["val_acc"])
        datasets.append(run.config["dataset"])
        best_val_acc = run.summary["arr_metrics"]["val_acc"][k]


        rows.append(
            dict(
                best_epoch=k,
                seed=seed, 
                lambda_task=run.config["lambda_task"],
                lambda_kd=run.config["lambda_kd"],
                # remark: this is the actual value used in distillation
                # cf. https://github.com/p16i/xai-kd/blob/2023-09-s14--1-teacher-training-script/scripts/distill-layerwise.py#L364
                lambda_layer=run.config["policy_lambda_layer"],
                val_acc=best_val_acc, 
                teacher_acc=run.summary["teacher_acc"],
                policy=run.config["policy"]
            )
        )

    if count != 0:
        print(f"We have {count} bad run! abort!")
        raise
    
    df = pd.DataFrame(rows)
    
    
    df = df.groupby(by="policy").agg(
        {
            "val_acc": ["mean", "std", "count"],
            "teacher_acc": ["mean"]
        }
    ).reset_index()
    np.testing.assert_allclose(
        df["val_acc"]["count"].values,
        3
    )
    
    if verbose:
        print(f"df.shape: {df.shape}")
    return df

summary = read_data(
    teacher="cifar100-resnet18-v1",
    student="resnet18dims32-24-24-5",
    dataset="cifar100-people",
    lambda_task=0.0,
    lambda_kd=1.0,
#     policy="basis-identity:pca--uncentered",
#     policy="nothing",
    policy="basis-identity:random--uncentered",

    training_size=1.0,
    verbose=True,
    contamination_level=0.25,
)

summary
# Out:
# we have 3 runs
# df.shape: (1, 5)
#                               policy val_acc                 teacher_acc
#                                         mean       std count        mean
# 0  basis-identity:random--uncentered   0.354  0.014422     3    0.614667

# %% [markdown]
# # Introduction

# %%
def ls(policy):
    if policy in ["fitnet", "attention-transfer", "vid"] :
        return ":"
    elif policy == "fitnetinvidbnrelu":
        return "-."
    else:
        return "-"
    
def marker(policy):
    return "."
    
    if "inner" in policy:
        return "."
    else:
        return None

def policy_alias(policy):
    _mapping = {
        "nothing": "KD only",
        "basis-identity:random--uncentered": "Random Subspace",
        "vid": "VID",
        "basis-identity:pca--uncentered": "PCA",
        "basis-identity:prca-sortabs--uncentered": "PRCA-sortabs",
    }
    
    return _mapping.get(policy, policy)

def layer_alias(layers):
    
    _mapping = {
        "layer1,layer2,layer3,layer4": "layer1,2,3,4",
        "layer2,layer3,layer4": "layer2,3,4",
        "layer3,layer4": "layer3,4",
        "layer4": "layer4",
    }
    
    return _mapping.get(layers, layers)

def bar_pattern(name):
    _mapping = {
        "nothing": "-",
        "vid": "+",
        "basis-identity:random--uncentered": ".",
        "basis-identity:pca--uncentered": "o",
        "basis-identity:prca-sortabs--uncentered": "*",
    }
    return _mapping[name]

    
def pretty_floats(mean, std):
    return ";".join(list(map(lambda v: f"{v[0]:.4f}({v[1]:.4f})", zip(mean, std))))

def viz_distillation_v2(
    teacher, 
    dataset,
    contamination_level,
    arr_students,
    arr_training_size,
    arr_policies,
    show_legend=True, 
):
        

    lambda_kd = 1.0
    lambda_task = 0.0
            
    col = "val_acc"
    
    
    ncols = len(arr_students)
    nrows = 1
    
    ntraining_size = len(arr_training_size)
    npolicies = len(arr_policies)
    
    plt.figure(figsize=(5*ncols, 3*nrows))
    
    dirslug = "/".join(f"{EXPERIMENT_GROUP}".split("/")[-2:])

    count = None
        
    ticks = np.arange(ntraining_size) 
    
    print(f"#### contamination-level={contamination_level} ####")
    for six, student in enumerate(arr_students):
        plt.subplot(nrows, ncols, six+1)
        print("")
        print(f"###### student={student}")
        for pix, policy in enumerate(arr_policies):
            stats = np.zeros(
                (ntraining_size, 2)
            )
            
            for tix, training_size in enumerate(arr_training_size):

                df = read_data(
                    teacher=teacher,
                    student=student,
                    dataset=dataset,
                    policy=policy,
                    lambda_task=lambda_task,
                    lambda_kd=lambda_kd,
                    training_size=training_size,
                    contamination_level=contamination_level,
                    verbose=False
                )
                count = df["val_acc"]["count"].values[0]
                mean =   df["val_acc"]["mean"].values[0]
                stderr =   df["val_acc"]["std"].values[0] / (count ** 0.5)
                stats[tix, :] = mean, stderr


            
                if "prca" in policy:

                    plt.plot(
                        [ticks[tix]*(npolicies+1)-0.5, ticks[tix]*(npolicies+1) + npolicies-0.5],
                        [mean]*2,
                        ls="-", lw=1,
                        color="k"
                    )
                    
                    if tix == 0:
                        teacher_acc = df["teacher_acc"]["mean"].values[0]
                        plt.axhline(
                            teacher_acc,
                            ls="--",
                            lw=1,
                            color="k",
                            label=f"Teacher ({teacher_acc:.4f})"
                        )
                        
            
            print(f"> policy={policy:>40s}: {pretty_floats(stats[:, 0], stats[:, 1])}")

            plt.bar(
                ticks*(npolicies+1)  + pix,
                stats[:, 0],
                xerr=stats[:, 1],
                hatch=bar_pattern(policy),
                label=policy_alias(policy)
            )
        plt.title(f"student={student}")


        

        plt.xticks(
            ticks*(npolicies+1) + ntraining_size // 2, 
            list(map(lambda p: f"{p*100:.1f}%", arr_training_size))
        )
        plt.xlabel("Training Size")
        if six == 0:
            plt.ylabel("Accuracy")
        else:
            plt.yticks([])
        if six == ncols-1:
            plt.legend(
                loc="center right",
                bbox_to_anchor=(1.55, 0.5)
            )

    plt.suptitle(
         "\n".join([
            f"dir: {dirslug}",
            f"teacher={teacher} ($\lambda_1$={lambda_task}, $\lambda_2$={lambda_kd})",
             f"dataset={dataset} (contamination_level={contamination_level}, #seed={count})"
        ]),
        y=1.2
    )
    plt.subplots_adjust(hspace=0.5, wspace=0.1)
    print("**************************\n")
    
viz_distillation_v2(
    teacher="cifar100-resnet18-v1",
    dataset="cifar100-people",
    contamination_level=0.25,
    arr_students=[
        "resnet18dims32-24-24-5",
#         "resnet18dims24-16-16-5",
#         "resnet18dims16-8-8-5",
    ],
    arr_training_size=[
        1.0,
        0.5,
        0.25,
        0.125
    ],
    arr_policies = [ 
#         "nothing",
#         "vid",
        "basis-identity:random--uncentered",
#         "basis-identity:pca--uncentered",
#         "basis-identity:prca-sortabs--uncentered",
    ],
)
# Out:
# #### contamination-level=0.25 ####
#
# ###### student=resnet18dims32-24-24-5
# > policy=       basis-identity:random--uncentered: 0.3540(0.0083);0.3387(0.0185);0.3213(0.0117);0.2860(0.0142)
# **************************

# %%
for lvl in [0.0, 0.25, 0.5, 0.75, 1.0]:
    viz_distillation_v2(
        teacher="cifar100-resnet18-v1",
        dataset="cifar100-people",
        contamination_level=lvl,
        arr_students=[
            "resnet18dims32-24-24-5",
            "resnet18dims24-16-16-5",
            "resnet18dims16-8-8-5",
        ],
        arr_training_size=[
            1.0,
            0.5,
            0.25,
            0.125
        ],
        arr_policies = [ 
            "nothing",
            "vid",
            "basis-identity:random--uncentered",
            "basis-identity:pca--uncentered",
            "basis-identity:prca-sortabs--uncentered",
        ],
    )
# Out:
# #### contamination-level=0.0 ####
#
# ###### student=resnet18dims32-24-24-5
# > policy=                                 nothing: 0.4887(0.0033);0.4140(0.0150);0.3767(0.0105);0.3427(0.0098)
# > policy=                                     vid: 0.4400(0.0179);0.3600(0.0127);0.3553(0.0221);0.3207(0.0127)
# > policy=       basis-identity:random--uncentered: 0.3553(0.0071);0.3360(0.0133);0.3147(0.0116);0.2767(0.0103)
# > policy=          basis-identity:pca--uncentered: 0.4800(0.0189);0.4287(0.0058);0.4113(0.0133);0.3647(0.0088)
# > policy= basis-identity:prca-sortabs--uncentered: 0.5140(0.0151);0.4547(0.0123);0.4120(0.0020);0.3653(0.0123)
#
# ###### student=resnet18dims24-16-16-5
# > policy=                                 nothing: 0.4467(0.0177);0.4067(0.0223);0.3553(0.0055);0.3520(0.0110)
# > policy=                                     vid: 0.3660(0.0284);0.3393(0.0093);0.3433(0.0205);0.3053(0.0077)
# > policy=       basis-identity:random--uncentered: 0.3360(0.0046);0.3180(0.0076);0.2887(0.0345);0.2620(0.0201)
# > policy=          basis-identity:pca--uncentered: 0.4647(0.0037);0.4040(0.0020);0.3813(0.0220);0.3287(0.0243)
# > policy= basis-identity:prca-sortabs--uncentered: 0.4487(0.0059);0.4140(0.0242);0.3807(0.0112);0.3487(0.0295)
#
# ###### student=resnet18dims16-8-8-5
# > policy=                                 nothing: 0.4047(0.0186);0.3820(0.0040);0.3473(0.0127);0.3313(0.0192)
# > policy=                                     vid: 0.3533(0.0134);0.3300(0.0181);0.2947(0.0144);0.2787(0.0231)
# > policy=       basis-identity:random--uncentered: 0.2900(0.0192);0.2680(0.0209);0.2680(0.0225);0.2680(0.0191)
# > policy=          basis-identity:pca--uncentered: 0.3780(0.0042);0.3487(0.0143);0.3380(0.0070);0.3200(0.0129)
# > policy= basis-identity:prca-sortabs--uncentered: 0.3853(0.0150);0.3540(0.0040);0.3073(0.0138);0.2927(0.0138)
# **************************
#
# #### contamination-level=0.25 ####
#
# ###### student=resnet18dims32-24-24-5
# > policy=                                 nothing: 0.4520(0.0151);0.4020(0.0076);0.3747(0.0120);0.3507(0.0133)
# > policy=                                     vid: 0.3860(0.0284);0.3513(0.0310);0.3593(0.0231);0.3033(0.0154)
# > policy=       basis-identity:random--uncentered: 0.3540(0.0083);0.3387(0.0185);0.3213(0.0117);0.2860(0.0142)
# > policy=          basis-identity:pca--uncentered: 0.4580(0.0092);0.4493(0.0101);0.4340(0.0101);0.3940(0.0061)
# > policy= basis-identity:prca-sortabs--uncentered: 0.4773(0.0191);0.4527(0.0077);0.4300(0.0012);0.3640(0.0194)
#
# ###### student=resnet18dims24-16-16-5
# > policy=                                 nothing: 0.4307(0.0109);0.3873(0.0167);0.3593(0.0018);0.3360(0.0110)
# > policy=                                     vid: 0.3347(0.0116);0.3467(0.0094);0.3280(0.0046);0.3167(0.0234)
# > policy=       basis-identity:random--uncentered: 0.3427(0.0044);0.3107(0.0087);0.3007(0.0464);0.2587(0.0254)
# > policy=          basis-identity:pca--uncentered: 0.4307(0.0085);0.4113(0.0107);0.3653(0.0140);0.3193(0.0227)
# > policy= basis-identity:prca-sortabs--uncentered: 0.4373(0.0044);0.4140(0.0189);0.3833(0.0228);0.3613(0.0087)
#
# ###### student=resnet18dims16-8-8-5
# > policy=                                 nothing: 0.3793(0.0007);0.3720(0.0035);0.3267(0.0033);0.3027(0.0067)
# > policy=                                     vid: 0.3307(0.0105);0.3087(0.0087);0.2980(0.0081);0.2813(0.0225)
# > policy=       basis-identity:random--uncentered: 0.2867(0.0180);0.2660(0.0216);0.2733(0.0210);0.2567(0.0320)
# > policy=          basis-identity:pca--uncentered: 0.3967(0.0116);0.3633(0.0131);0.3353(0.0147);0.3073(0.0174)
# > policy= basis-identity:prca-sortabs--uncentered: 0.3987(0.0048);0.3660(0.0092);0.3413(0.0098);0.2887(0.0073)
# **************************
#
# #### contamination-level=0.5 ####
#
# ###### student=resnet18dims32-24-24-5
# > policy=                                 nothing: 0.3613(0.0105);0.3347(0.0207);0.3387(0.0138);0.3313(0.0093)
# > policy=                                     vid: 0.3007(0.0013);0.2973(0.0027);0.2967(0.0053);0.2980(0.0277)
# > policy=       basis-identity:random--uncentered: 0.3380(0.0076);0.3207(0.0139);0.3160(0.0175);0.2840(0.0072)
# > policy=          basis-identity:pca--uncentered: 0.4427(0.0116);0.4053(0.0103);0.4187(0.0163);0.3453(0.0278)
# > policy= basis-identity:prca-sortabs--uncentered: 0.4680(0.0103);0.4360(0.0170);0.4260(0.0035);0.3393(0.0181)
#
# ###### student=resnet18dims24-16-16-5
# > policy=                                 nothing: 0.3460(0.0145);0.3380(0.0204);0.3413(0.0141);0.3107(0.0155)
# > policy=                                     vid: 0.2967(0.0127);0.3053(0.0066);0.3353(0.0154);0.2780(0.0216)
# > policy=       basis-identity:random--uncentered: 0.3347(0.0067);0.3180(0.0170);0.2900(0.0342);0.2667(0.0233)
# > policy=          basis-identity:pca--uncentered: 0.4180(0.0140);0.3600(0.0160);0.3727(0.0081);0.3233(0.0127)
# > policy= basis-identity:prca-sortabs--uncentered: 0.4533(0.0118);0.4287(0.0174);0.3620(0.0212);0.3193(0.0238)
#
# ###### student=resnet18dims16-8-8-5
# > policy=                                 nothing: 0.3287(0.0148);0.3193(0.0085);0.3147(0.0183);0.2867(0.0121)
# > policy=                                     vid: 0.2973(0.0139);0.2900(0.0131);0.3267(0.0077);0.2613(0.0244)
# > policy=       basis-identity:random--uncentered: 0.2933(0.0041);0.2587(0.0145);0.2573(0.0157);0.2467(0.0139)
# > policy=          basis-identity:pca--uncentered: 0.3793(0.0168);0.3413(0.0139);0.3500(0.0081);0.3160(0.0035)
# > policy= basis-identity:prca-sortabs--uncentered: 0.3873(0.0140);0.3573(0.0024);0.3360(0.0095);0.2987(0.0111)
# **************************
#
# #### contamination-level=0.75 ####
#
# ###### student=resnet18dims32-24-24-5
# > policy=                                 nothing: 0.3187(0.0144);0.3107(0.0162);0.3240(0.0271);0.2980(0.0164)
# > policy=                                     vid: 0.2753(0.0158);0.2513(0.0007);0.2893(0.0107);0.2780(0.0087)
# > policy=       basis-identity:random--uncentered: 0.3107(0.0117);0.3033(0.0127);0.2960(0.0122);0.2867(0.0027)
# > policy=          basis-identity:pca--uncentered: 0.3940(0.0145);0.3520(0.0210);0.3813(0.0271);0.3207(0.0147)
# > policy= basis-identity:prca-sortabs--uncentered: 0.3927(0.0164);0.4020(0.0081);0.3780(0.0064);0.3680(0.0186)
#
# ###### student=resnet18dims24-16-16-5
# > policy=                                 nothing: 0.3107(0.0260);0.3040(0.0266);0.3220(0.0250);0.2767(0.0145)
# > policy=                                     vid: 0.2627(0.0129);0.2580(0.0081);0.2640(0.0046);0.2913(0.0087)
# > policy=       basis-identity:random--uncentered: 0.3200(0.0151);0.2920(0.0072);0.2847(0.0327);0.2807(0.0240)
# > policy=          basis-identity:pca--uncentered: 0.3627(0.0157);0.3407(0.0197);0.3647(0.0232);0.2953(0.0144)
# > policy= basis-identity:prca-sortabs--uncentered: 0.4067(0.0294);0.3880(0.0345);0.3553(0.0057);0.3587(0.0139)
#
# ###### student=resnet18dims16-8-8-5
# > policy=                                 nothing: 0.2880(0.0280);0.2993(0.0350);0.2960(0.0280);0.2813(0.0228)
# > policy=                                     vid: 0.3027(0.0270);0.3113(0.0079);0.3120(0.0172);0.2753(0.0171)
# > policy=       basis-identity:random--uncentered: 0.2620(0.0023);0.2553(0.0127);0.2580(0.0142);0.2373(0.0164)
# > policy=          basis-identity:pca--uncentered: 0.3700(0.0200);0.3433(0.0134);0.3347(0.0105);0.3007(0.0082)
# > policy= basis-identity:prca-sortabs--uncentered: 0.3720(0.0120);0.3633(0.0107);0.3260(0.0042);0.2900(0.0223)
# **************************
#
# #### contamination-level=1.0 ####
#
# ###### student=resnet18dims32-24-24-5
# > policy=                                 nothing: 0.2760(0.0190);0.2787(0.0290);0.2800(0.0174);0.2827(0.0309)
# > policy=                                     vid: 0.2547(0.0188);0.2500(0.0150);0.2613(0.0037);0.2627(0.0044)
# > policy=       basis-identity:random--uncentered: 0.2793(0.0118);0.2820(0.0133);0.2827(0.0047);0.2707(0.0047)
# > policy=          basis-identity:pca--uncentered: 0.3433(0.0305);0.3253(0.0254);0.3467(0.0307);0.2973(0.0121)
# > policy= basis-identity:prca-sortabs--uncentered: 0.3840(0.0265);0.3647(0.0184);0.3480(0.0231);0.3373(0.0201)
#
# ###### student=resnet18dims24-16-16-5
# > policy=                                 nothing: 0.2793(0.0277);0.2853(0.0365);0.2787(0.0311);0.2820(0.0284)
# > policy=                                     vid: 0.2793(0.0109);0.2533(0.0125);0.2460(0.0183);0.2853(0.0143)
# > policy=       basis-identity:random--uncentered: 0.2940(0.0174);0.2780(0.0099);0.2713(0.0202);0.2707(0.0105)
# > policy=          basis-identity:pca--uncentered: 0.2960(0.0197);0.2760(0.0178);0.3407(0.0199);0.2913(0.0079)
# > policy= basis-identity:prca-sortabs--uncentered: 0.3900(0.0410);0.3647(0.0279);0.3440(0.0250);0.3160(0.0242)
#
# ###### student=resnet18dims16-8-8-5
# > policy=                                 nothing: 0.2687(0.0277);0.2507(0.0254);0.2753(0.0236);0.2513(0.0199)
# > policy=                                     vid: 0.2740(0.0061);0.2887(0.0174);0.2587(0.0176);0.2527(0.0152)
# > policy=       basis-identity:random--uncentered: 0.2493(0.0055);0.2427(0.0111);0.2453(0.0139);0.2407(0.0098)
# > policy=          basis-identity:pca--uncentered: 0.3553(0.0141);0.3400(0.0174);0.3273(0.0093);0.3033(0.0068)
# > policy= basis-identity:prca-sortabs--uncentered: 0.3347(0.0131);0.3087(0.0260);0.3100(0.0095);0.2833(0.0146)
# **************************

# %% [markdown]
# # Summary (to write)
#
#
# *Conclusion:*
# ...

# %%
12.5 / 2
# Out:
# 6.25
