# %%
from xaikd import models, utils

# %%
teacher = models.get_trained_model("imagenet-vgg16-tv")

"%.1e" % utils.count_params_in_model(teacher)[0]
# Out:
# '1.4e+08'

# %%
student = models.get_untrained_model("vggcustomimagenetdims-32-24-24-10", num_classes=6)

"%.1e" % utils.count_params_in_model(student)[0]
# Out:
# '8.3e+04'

# %%
138357544/82640
# Out:
# 1674.2200387221685
