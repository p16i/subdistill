# %%
import numpy as np

from matplotlib import pyplot as plt

# %%
weights = np.load("../../tmp/mnist-k14-h128-n7000/act1/models/k5-lm1-lx0/weight.npy")

# %%
weights.shape
# Out:
# (10, 1, 14, 14)

# %%
plt.figure(figsize=(1*10, 1))
ncols = 10

for i in range(weights.shape[0]):
    plt.subplot(1, ncols, i+1)
    
    plt.imshow(weights[i].squeeze())
