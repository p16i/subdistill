# %%
import lxt.functional as lf

# %%
import torch
import open_clip
import itertools
from PIL import Image

import lxt.functional as lf
from lxt.models.openclip import attnlrp
from zennit.composites import LayerMapComposite
import zennit.rules as z_rules
from zennit.image import imgify


device = 'cpu'

# Load the model and the tokenizer
model, _, preprocess = open_clip.create_model_and_transforms('ViT-g-14', pretrained='laion2b_s34b_b88k')
model.eval()
model = model.to(device)

tokenizer = open_clip.get_tokenizer('ViT-g-14')

# Load an image and tokenize a text
text = tokenizer(['a beautiful LRP heatmap', 'a dog', 'a cat']).to(device)
image = preprocess(Image.open('/home/pat/Downloads/cat_dog.jpg')).unsqueeze(0).to(device)

# trace the model with a dummy input
# verbose=True prints all functions/layers found and replaced by LXT
# you will see at the last entry that e.g. tensor.exp() is not supported by LXT. This is not a problem in our case,
# because this function is not used in the backward pass and therefore does not need to be replaced.
# (look into the open_clip.transformer module code!)
x = torch.randn(1, 3, 224, 224, device=device)
traced = attnlrp.register(model, dummy_inputs={'image': x, 'text': text}, verbose=True)

# for Vision Transformer, we must perform a grid search for the best gamma hyperparameters
# in general, it is enough to concentrate on the Conv2d and MLP layers
# for simplicity we just use a few values that can be evaluated by hand & looking at the heatmaps
heatmaps = []
for conv_gamma, lin_gamma in itertools.product([0.1, 0.5, 100], [0, 0.01, 0.05, 0.1, 1]):

    print("Gamma Conv2d:", conv_gamma, "Gamma Linear:", lin_gamma)

    # we define rules for the Conv2d and Linear layers using 'Zennit'
    zennit_comp = LayerMapComposite([
            (torch.nn.Conv2d, z_rules.Gamma(conv_gamma)),
            (torch.nn.Linear, z_rules.Gamma(lin_gamma)),
        ])

    # register composite
    zennit_comp.register(traced)

    # forward & backward pass
    y = traced(image.requires_grad_(True), text)
    logits = lf.matmul(y[0], y[1].transpose(0, 1))

    # explain the dog class ("a dog")
    image.grad = None
    logits[0, 1].backward()

    # normalize the heatmap
    heatmap = image.grad[0].sum(0)
    heatmap = heatmap / abs(heatmap).max()
    heatmaps.append(heatmap.cpu().numpy())

    # zennit composites can be removed so that we can register a new one!
    zennit_comp.remove()

# save the heatmaps as a grid
imgify(heatmaps, vmin=-1, vmax=1, grid=(3, 5))
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[7], line 32
#      26 # trace the model with a dummy input
#      27 # verbose=True prints all functions/layers found and replaced by LXT
#      28 # you will see at the last entry that e.g. tensor.exp() is not supported by LXT. This is not a problem in our case,
#      29 # because this function is not used in the backward pass and therefore does not need to be replaced.
#      30 # (look into the open_clip.transformer module code!)
#      31 x = torch.randn(1, 3, 224, 224, device=device)
# ---> 32 traced = attnlrp.register(model, dummy_inputs={'image': x, 'text': text}, verbose=True)
#      34 # for Vision Transformer, we must perform a grid search for the best gamma hyperparameters
#      35 # in general, it is enough to concentrate on the Conv2d and MLP layers
#      36 # for simplicity we just use a few values that can be evaluated by hand & looking at the heatmaps
#      37 heatmaps = []
#
# File ~/projects/xai-kd/.venv/lib/python3.10/site-packages/lxt/core.py:78, in Composite.register(self, parent, dummy_inputs, tracer, verbose, no_grad)
#      76 module_map, fn_map = self._parse_rules(self.layer_map)
#      77 if module_map:
# ---> 78     self._iterate_children(parent, module_map)
#      80 if fn_map or dummy_inputs:
#      81     parent = self._iterate_graph(parent, dummy_inputs, fn_map, module_map, tracer)
#
# File ~/projects/xai-kd/.venv/lib/python3.10/site-packages/lxt/core.py:117, in Composite._iterate_children(self, parent, rule_dict)
#     114 for name, child in parent.named_children():
#     116     child = self._attach_module_rule(child, parent, name, rule_dict)
# --> 117     self._iterate_children(child, rule_dict)
#
# File ~/projects/xai-kd/.venv/lib/python3.10/site-packages/lxt/core.py:116, in Composite._iterate_children(self, parent, rule_dict)
#     110 """
#     111 Recursive function to iterate through the children of a module and attach the rules to the modules.
#     112 """
#     114 for name, child in parent.named_children():
# --> 116     child = self._attach_module_rule(child, parent, name, rule_dict)
#     117     self._iterate_children(child, rule_dict)
#
# File ~/projects/xai-kd/.venv/lib/python3.10/site-packages/lxt/core.py:137, in Composite._attach_module_rule(self, child, parent, name, rule_dict)
#     133     xai_module = rule(child)
#     134 elif issubclass(rule, nn.Module):
#     135     # replace module with LXT.module and attach it to parent as attribute
#     136     # INIT_MODULE_MAPPING contains the correct function for initializing and copying the parameters and buffers
# --> 137     xai_module = INIT_MODULE_MAPPING[rule](child, rule)
#     138     # return the new module to iterate through its children to attach the rules
#     139     child = xai_module
#
# File ~/projects/xai-kd/.venv/lib/python3.10/site-packages/lxt/modules.py:167, in initialize_bias(original, replacement)
#     163         kwargs[arg] = getattr(original, arg)
#     165 kwargs["bias"] = True if original.bias is not None else False
# --> 167 replacement = replacement(**kwargs)
#     168 copy_parameters_and_buffers_(original, replacement)
#     170 return replacement
#
# File ~/projects/xai-kd/.venv/lib/python3.10/site-packages/lxt/modules.py:51, in LayerNormEpsilon.__init__(self, normalized_shape, eps, elementwise_affine, bias, device, dtype)
#      50 def __init__(self, normalized_shape, eps: float = 0.00001, elementwise_affine: bool = True, bias: bool = True, device=None, dtype=None):
# ---> 51     super().__init__(normalized_shape, eps, elementwise_affine, bias, device, dtype)
#
# TypeError: LayerNorm.__init__() takes from 2 to 6 positional arguments but 7 were given
