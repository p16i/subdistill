# %%
from xaikd import models, datasets, constants, metrics

from torch import nn

from tqdm.autonotebook import tqdm

# %%
def compute_auroc_superclass(dataset_name):
    dataset = datasets.construct(dataset_name)
    model = nn.Sequential(
        models.get_trained_model("cifar100-resnet18-v1"),
        models.layers.LayerLogOddSelectedClasses(selected_classes=dataset.selected_classes)
    ).eval()
    
    
    ds_test = dataset.create_subset(train_split=False)
    dl = datasets.build_dataloader(ds_test, shuffle=False)
    
    
    metric = metrics.MetricAUROCBinaryCrossEntropy()
    
    auroc, loss = metric(model=model, dataloader=dl, device="cpu", verbose=True)
    return dict(dataset_name=dataset_name, auroc=auroc, loss=loss)
    
compute_auroc_superclass("cifar100-large_man_made_outdoor_things-vs-others")
# Out:
# /home/pat/projects/xai-kd/.venv/lib/python3.11/site-packages/torch/utils/data/dataloader.py:561: UserWarning: This DataLoader will create 12 worker processes in total. Our suggested max number of worker in current system is 8, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   warnings.warn(_create_warning_msg(
# Computing AUROC: 100%|█████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 157/157 [01:39<00:00,  1.58it/s]
# {'dataset_name': 'cifar100-large_man_made_outdoor_things-vs-others',
#  'auroc': 0.9961483478546143,
#  'loss': 0.023136276751756668}

# %%
compute_auroc_superclass("cifar100-people-vs-others")
# Out:
# Computing AUROC: 100%|█████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 157/157 [01:39<00:00,  1.57it/s]
# {'dataset_name': 'cifar100-people-vs-others',
#  'auroc': 0.9949838519096375,
#  'loss': 0.025606252253055573}

# %%
compute_auroc_superclass("cifar100-aquatic_mammals-vs-others")
# Out:
# Computing AUROC: 100%|█████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 157/157 [01:46<00:00,  1.48it/s]
# {'dataset_name': 'cifar100-aquatic_mammals-vs-others',
#  'auroc': 0.9715427160263062,
#  'loss': 0.06789059937000275}
